# %% [markdown]
# ## Model Testing
#
# This step verifies that the model can process input images and produce output logits.
# It ensures the forward pass works correctly before training.

# %%
import sys
sys.path.append("..")

# %%
import torch
from src.model import get_model
from src.dataloader import get_dataloaders

# %%
train_loader, _ = get_dataloaders(
    train_csv="../data/train.csv",
    val_csv="../data/val.csv",
    image_dir="../data/raw_data/ISIC_2024_Training_Input",
    batch_size=8
)

model = get_model()
images, labels = next(iter(train_loader))
outputs = model(images)

print("Input shape:", images.shape)
print("Output shape:", outputs.shape)
# Out:
# c:\Users\phang\DATN\venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\phang\DATN\venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\phang/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100.0%
# Input shape: torch.Size([8, 3, 224, 224])
# Output shape: torch.Size([8, 1])
