# %% [markdown]
# ## Image Transforms
#
# This step defines image preprocessing transformations such as resizing and normalization.
# Transforms ensure consistent input size and improve model convergence during training.

# %%
import sys
sys.path.append("..")

# %%
from src.dataset import ISICDataset
from src.transforms import get_train_transforms

# %%
dataset = ISICDataset(
    csv_file="../data/train.csv",
    image_dir="../data/raw_data/ISIC_2024_Training_Input",
    transform=get_train_transforms()
)

img, label = dataset[0]

print(img.shape)
print(label)
# Out:
# torch.Size([3, 224, 224])
# 0.0
